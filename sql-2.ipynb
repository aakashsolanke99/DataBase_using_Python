# %%
import mysql.connector as conn

# %%
mydb=conn.connect(host="localhost",user="root",passwd="Aakash@123")

# %%
cursor=mydb.cursor()

# %%
cursor.execute("show databases")

# %%
cursor.fetchall()
# Out:
# [('awesome_chocolates',),
#  ('car',),
#  ('classicmodels',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sql_intro',),
#  ('sql_joins',),
#  ('sys',),
#  ('testsudh',),
#  ('triggers',)]

# %%
cursor.execute("select * from testsudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testsudh.ineuron")

# %%
cursor.fetchall()
# Out:
# [(101, 'sudh', 'kumar', 2345436, 'FSDS'),
#  (102, 'aakash', 'solanke', 2323536, 'FSDS-1'),
#  (103, 'hemlata', 'malve', 23222536, 'java'),
#  (104, 'aniket', 'patil', 23287636, 'ML'),
#  (103, 'Ankita', 'yetale', 2334536, 'AL-ML')]

# %%
cursor.execute("select col3, col2, col5 from testsudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(13.64, 1.52101, 1.1),
#  (13.89, 1.51761, 1.36),
#  (13.53, 1.51618, 1.54),
#  (13.27, 1.51742, 1.24),
#  (12.79, 1.51596, 1.62),
#  (13.3, 1.51743, 1.14),
#  (13.15, 1.51756, 1.05),
#  (14.04, 1.51918, 1.37),
#  (13.0, 1.51755, 1.36),
#  (12.72, 1.51571, 1.56),
#  (12.8, 1.51763, 1.27),
#  (12.88, 1.51589, 1.4),
#  (12.86, 1.51748, 1.27),
#  (12.61, 1.51763, 1.31),
#  (12.81, 1.51761, 1.23),
#  (12.68, 1.51784, 1.16),
#  (14.36, 1.52196, 0.89),
#  (13.9, 1.51911, 1.18),
#  (13.02, 1.51735, 1.69),
#  (12.82, 1.5175, 1.49),
#  (14.77, 1.51966, 0.29),
#  (12.78, 1.51736, 1.29),
#  (12.81, 1.51751, 1.35),
#  (13.38, 1.5172, 1.15),
#  (12.98, 1.51764, 1.21),
#  (13.21, 1.51793, 1.41),
#  (12.87, 1.51721, 1.33),
#  (12.56, 1.51768, 1.43),
#  (13.08, 1.51784, 1.28),
#  (12.65, 1.51768, 1.3),
#  (12.84, 1.51747, 1.14),
#  (12.85, 1.51775, 1.23),
#  (12.57, 1.51753, 1.38),
#  (12.69, 1.51783, 1.34),
#  (13.29, 1.51567, 1.21),
#  (13.89, 1.51909, 1.32),
#  (12.74, 1.51797, 1.35),
# ...

# %%
cursor.execute("select * from testsudh.glassdata where col1=4")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select * from testsudh.glassdata where col1=4 and col11=1")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("delete from testsudh.glassdata where col1=4")

# %%
mydb.commit()

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select * from testsudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(1, 1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testsudh.glassdata where col1=4 and col11=1")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("update testsudh.glassdata SET col1=6 , col2=8 where col1=1")

# %%
mydb.commit()

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select * from testsudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testsudh.glassdata where col1=6 ")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cursor.execute("select count(col1),col2 from testsudh.glassdata group by col1")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0),
#  (3, 1.51761),
#  (3, 1.51618),
#  (3, 1.51742),
#  (3, 1.51743),
#  (3, 1.51756),
#  (3, 1.51918),
#  (3, 1.51755),
#  (3, 1.51571),
#  (3, 1.51763),
#  (3, 1.51589),
#  (3, 1.51748),
#  (3, 1.51763),
#  (3, 1.51761),
#  (3, 1.51784),
#  (3, 1.52196),
#  (3, 1.51911),
#  (3, 1.51735),
#  (3, 1.5175),
#  (3, 1.51966),
#  (3, 1.51736),
#  (3, 1.51751),
#  (3, 1.5172),
#  (3, 1.51764),
#  (3, 1.51793),
#  (3, 1.51721),
#  (3, 1.51768),
#  (3, 1.51784),
#  (3, 1.51768),
#  (3, 1.51747),
#  (3, 1.51775),
#  (3, 1.51753),
#  (3, 1.51783),
#  (3, 1.51567),
#  (3, 1.51909),
#  (3, 1.51797),
#  (3, 1.52213),
#  (3, 1.52213),
#  (3, 1.51793),
#  (3, 1.51755),
#  (3, 1.51779),
#  (3, 1.5221),
#  (3, 1.51786),
#  (3, 1.519),
#  (3, 1.51869),
#  (3, 1.52667),
#  (3, 1.52223),
#  (3, 1.51898),
#  (3, 1.5232),
#  (3, 1.51926),
#  (3, 1.51808),
#  (3, 1.51837),
#  (3, 1.51778),
#  (3, 1.51769),
#  (3, 1.51215),
#  (3, 1.51824),
#  (3, 1.51754),
#  (3, 1.51754),
#  (3, 1.51905),
# ...

# %%
cursor.execute("select col1, count(col1), col11 from testsudh.glassdata group by col1")

# %%
cursor.fetchall()
# Out:
# [(6, 6, 1),
#  (2, 3, 1),
#  (3, 3, 1),
#  (5, 3, 1),
#  (7, 3, 1),
#  (8, 3, 1),
#  (9, 3, 1),
#  (10, 3, 1),
#  (11, 3, 1),
#  (12, 3, 1),
#  (13, 3, 1),
#  (14, 3, 1),
#  (15, 3, 1),
#  (16, 3, 1),
#  (17, 3, 1),
#  (18, 3, 1),
#  (19, 3, 1),
#  (20, 3, 1),
#  (21, 3, 1),
#  (22, 3, 1),
#  (23, 3, 1),
#  (24, 3, 1),
#  (25, 3, 1),
#  (26, 3, 1),
#  (27, 3, 1),
#  (28, 3, 1),
#  (29, 3, 1),
#  (30, 3, 1),
#  (31, 3, 1),
#  (32, 3, 1),
#  (33, 3, 1),
#  (34, 3, 1),
#  (35, 3, 1),
#  (36, 3, 1),
#  (37, 3, 1),
#  (38, 3, 1),
#  (39, 3, 1),
#  (40, 3, 1),
#  (41, 3, 1),
#  (42, 3, 1),
#  (43, 3, 1),
#  (44, 3, 1),
#  (45, 3, 1),
#  (46, 3, 1),
#  (47, 3, 1),
#  (48, 3, 1),
#  (49, 3, 1),
#  (50, 3, 1),
#  (51, 3, 1),
#  (52, 3, 1),
#  (53, 3, 1),
#  (54, 3, 1),
#  (55, 3, 1),
#  (56, 3, 1),
#  (57, 3, 1),
#  (58, 3, 1),
#  (59, 3, 1),
#  (60, 3, 1),
#  (61, 3, 1),
#  (62, 3, 1),
#  (63, 3, 1),
#  (64, 3, 1),
#  (65, 3, 1),
#  (66, 3, 1),
#  (67, 3, 1),
#  (68, 3, 1),
#  (69, 3, 1),
# ...

# %%
cursor.execute("select * from testsudh.glassdata where col1=6")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1)]

# %%
cursor.execute("select col1 ,count(*) from testsudh.glassdata group by col1 order by col1")

# %%
cursor.fetchall()
# Out:
# [(2, 3),
#  (3, 3),
#  (5, 3),
#  (6, 6),
#  (7, 3),
#  (8, 3),
#  (9, 3),
#  (10, 3),
#  (11, 3),
#  (12, 3),
#  (13, 3),
#  (14, 3),
#  (15, 3),
#  (16, 3),
#  (17, 3),
#  (18, 3),
#  (19, 3),
#  (20, 3),
#  (21, 3),
#  (22, 3),
#  (23, 3),
#  (24, 3),
#  (25, 3),
#  (26, 3),
#  (27, 3),
#  (28, 3),
#  (29, 3),
#  (30, 3),
#  (31, 3),
#  (32, 3),
#  (33, 3),
#  (34, 3),
#  (35, 3),
#  (36, 3),
#  (37, 3),
#  (38, 3),
#  (39, 3),
#  (40, 3),
#  (41, 3),
#  (42, 3),
#  (43, 3),
#  (44, 3),
#  (45, 3),
#  (46, 3),
#  (47, 3),
#  (48, 3),
#  (49, 3),
#  (50, 3),
#  (51, 3),
#  (52, 3),
#  (53, 3),
#  (54, 3),
#  (55, 3),
#  (56, 3),
#  (57, 3),
#  (58, 3),
#  (59, 3),
#  (60, 3),
#  (61, 3),
#  (62, 3),
#  (63, 3),
#  (64, 3),
#  (65, 3),
#  (66, 3),
#  (67, 3),
#  (68, 3),
#  (69, 3),
#  (70, 3),
#  (71, 3),
#  (72, 3),
#  (73, 3),
#  (74, 3),
#  (75, 3),
#  (76, 3),
#  (77, 3),
#  (78, 3),
#  (79, 3),
#  (80, 3),
#  (81, 3),
#  (82, 3),
#  (83, 3),
#  (84, 3),
#  (85, 3),
# ...

# %%
cursor.execute("select * from testsudh.ineuron")

# %%
cursor.fetchall()
# Out:
# [(101, 'sudh', 'kumar', 2345436, 'FSDS'),
#  (102, 'aakash', 'solanke', 2323536, 'FSDS-1'),
#  (103, 'hemlata', 'malve', 23222536, 'java'),
#  (104, 'aniket', 'patil', 23287636, 'ML'),
#  (103, 'Ankita', 'yetale', 2334536, 'AL-ML')]

# %%
cursor.execute("select count(*) from testsudh.ineuron where classname='FSDS' ")

# %%
cursor.fetchall()
# Out:
# [(1,)]

# %%
cursor.execute("select * from testsudh.ineuron where classname='FSDS' ")

# %%
cursor.fetchall()
# Out:
# [(101, 'sudh', 'kumar', 2345436, 'FSDS')]

# %%
cursor.execute("select count(*),studentid from testsudh.ineuron group by studentid='101' ")

# %%
cursor.fetchall()
# Out:
# [(1, 101), (4, 102)]

# %%
cursor.execute("select * from testsudh.glassdata ")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testsudh.glassdata where col1=11 or col11=2")

# %%
cursor.fetchall()
# Out:
# [(11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (72, 1.51848, 13.64, 3.87, 1.27, 71.96, 0.54, 8.32, 0.0, 0.32, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (74, 1.51631, 13.34, 3.57, 1.57, 72.87, 0.61, 7.89, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (77, 1.51645, 13.44, 3.61, 1.54, 72.39, 0.66, 8.03, 0.0, 0.0, 2),
#  (78, 1.51627, 13.0, 3.58, 1.54, 72.83, 0.61, 8.04, 0.0, 0.0, 2),
#  (79, 1.51613, 13.92, 3.52, 1.25, 72.88, 0.37, 7.94, 0.0, 0.14, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (83, 1.51646, 13.41, 3.55, 1.25, 72.81, 0.68, 8.1, 0.0, 0.0, 2),
# ...

# %%
cursor.execute("select * from testsudh.glassdata where col1=11 and col11=2")

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute("select * from testsudh.glassdata where col2 like '1.515%' ")   #  % is place holder

# %%
cursor.fetchall()
# Out:
# [(6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (36, 1.51567, 13.29, 3.45, 1.21, 72.74, 0.56, 8.57, 0.0, 0.0, 1),
#  (71, 1.51574, 14.86, 3.67, 1.74, 71.87, 0.16, 7.36, 0.0, 0.12, 2),
#  (73, 1.51593, 13.09, 3.59, 1.52, 73.1, 0.67, 7.83, 0.0, 0.0, 2),
#  (75, 1.51596, 13.02, 3.56, 1.54, 73.11, 0.72, 7.9, 0.0, 0.0, 2),
#  (76, 1.5159, 13.02, 3.58, 1.51, 73.12, 0.69, 7.96, 0.0, 0.0, 2),
#  (80, 1.5159, 12.82, 3.52, 1.9, 72.86, 0.69, 7.97, 0.0, 0.0, 2),
#  (81, 1.51592, 12.86, 3.52, 2.12, 72.66, 0.69, 7.97, 0.0, 0.0, 2),
#  (82, 1.51593, 13.25, 3.45, 1.43, 73.17, 0.61, 7.86, 0.0, 0.0, 2),
#  (84, 1.51594, 13.09, 3.52, 1.55, 72.87, 0.68, 8.05, 0.0, 0.09, 2),
#  (87, 1.51569, 13.24, 3.49, 1.47, 73.25, 0.38, 8.03, 0.0, 0.0, 2),
#  (93, 1.51588, 13.12, 3.41, 1.58, 73.26, 0.07, 8.39, 0.0, 0.19, 2),
# ...

# %%
cursor.execute("select * from testsudh.glassdata order by col2 desc")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (108, 1.53393, 12.3, 0.0, 1.0, 70.16, 0.12, 16.19, 0.0, 0.24, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (107, 1.53125, 10.73, 0.0, 2.1, 69.81, 0.58, 13.3, 3.15, 0.28, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (113, 1.52777, 12.64, 0.0, 0.67, 72.02, 0.06, 14.4, 0.0, 0.0, 2),
#  (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2),
#  (112, 1.52739, 11.02, 0.0, 0.75, 73.08, 0.0, 14.96, 0.0, 0.0, 2),
# ...

# %%
cursor.execute("select * from (select * from testsudh.glassdata where col1>112) as a where col11=3 ")

# %%
cursor.fetchall()
# Out:
# [(147, 1.51769, 13.65, 3.66, 1.11, 72.77, 0.11, 8.6, 0.0, 0.0, 3),
#  (148, 1.5161, 13.33, 3.53, 1.34, 72.67, 0.56, 8.33, 0.0, 0.0, 3),
#  (149, 1.5167, 13.24, 3.57, 1.38, 72.7, 0.56, 8.44, 0.0, 0.1, 3),
#  (150, 1.51643, 12.16, 3.52, 1.35, 72.89, 0.57, 8.53, 0.0, 0.0, 3),
#  (151, 1.51665, 13.14, 3.45, 1.76, 72.48, 0.6, 8.38, 0.0, 0.17, 3),
#  (152, 1.52127, 14.32, 3.9, 0.83, 71.5, 0.0, 9.49, 0.0, 0.0, 3),
#  (153, 1.51779, 13.64, 3.65, 0.65, 73.0, 0.06, 8.93, 0.0, 0.0, 3),
#  (154, 1.5161, 13.42, 3.4, 1.22, 72.69, 0.59, 8.32, 0.0, 0.0, 3),
#  (155, 1.51694, 12.86, 3.58, 1.31, 72.61, 0.61, 8.79, 0.0, 0.0, 3),
#  (156, 1.51646, 13.04, 3.4, 1.26, 73.01, 0.52, 8.58, 0.0, 0.0, 3),
#  (157, 1.51655, 13.41, 3.39, 1.28, 72.64, 0.52, 8.65, 0.0, 0.0, 3),
#  (158, 1.52121, 14.03, 3.76, 0.58, 71.79, 0.11, 9.65, 0.0, 0.0, 3),
#  (159, 1.51776, 13.53, 3.41, 1.52, 72.04, 0.58, 8.79, 0.0, 0.0, 3),
#  (160, 1.51796, 13.5, 3.36, 1.63, 71.94, 0.57, 8.81, 0.0, 0.09, 3),
# ...

# %%
cursor.execute("select * from testsudh.glassdata")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (6, 1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
# ...

# %%
cursor.execute("select * from testsudh.glassdata group by col1 having count(col1)>2 ")

# %%
cursor.fetchall()
# Out:
# [(6, 8.0, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1),
#  (2, 1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1),
#  (3, 1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1),
#  (5, 1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1),
#  (7, 1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1),
#  (8, 1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1),
#  (9, 1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1),
#  (10, 1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1),
#  (11, 1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1),
#  (12, 1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1),
#  (13, 1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1),
#  (14, 1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1),
#  (15, 1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1),
#  (16, 1.51761, 12.81, 3.54, 1.23, 73.24, 0.58, 8.39, 0.0, 0.0, 1),
# ...

# %% [markdown]
# - take a deta set from attached url
# - create databas as car dataset
# - create table called as car with column name given in dataset description
# - dump all the data into car table
# - try to cheak weather all the data is avilable inside your table or not
# - try to group all the data with col3 and count occurance of each and every record based on col1 value
# - try to filter a record where col 3 value will be 4
# - try to update a col 3 value with 8 where you have value equal to 2
# - try to delete table
# - try to delete database

# %%
cursor.execute("create database car")

# %%
cursor.execute("create table car.car1( buying VARCHAR(20), maint VARCHAR(20), doors INT(10), persons INT(10), lug_boot VARCHAR(20), safety VARCHAR(20),class VARCHAR(20))")

# %%
cursor.execute("use car")

# %%
cursor.execute("show tables")

# %%
cursor.fetchall()
# Out:
# [('car',), ('car1',)]

# %%
file = open("car.data","r")

# %%
file.read()
# Out:
# 'vhigh,vhigh,2,2,small,low,unacc\nvhigh,vhigh,2,2,small,med,unacc\nvhigh,vhigh,2,2,small,high,unacc\nvhigh,vhigh,2,2,med,low,unacc\nvhigh,vhigh,2,2,med,med,unacc\nvhigh,vhigh,2,2,med,high,unacc\nvhigh,vhigh,2,2,big,low,unacc\nvhigh,vhigh,2,2,big,med,unacc\nvhigh,vhigh,2,2,big,high,unacc\nvhigh,vhigh,2,4,small,low,unacc\nvhigh,vhigh,2,4,small,med,unacc\nvhigh,vhigh,2,4,small,high,unacc\nvhigh,vhigh,2,4,med,low,unacc\nvhigh,vhigh,2,4,med,med,unacc\nvhigh,vhigh,2,4,med,high,unacc\nvhigh,vhigh,2,4,big,low,unacc\nvhigh,vhigh,2,4,big,med,unacc\nvhigh,vhigh,2,4,big,high,unacc\nvhigh,vhigh,2,more,small,low,unacc\nvhigh,vhigh,2,more,small,med,unacc\nvhigh,vhigh,2,more,small,high,unacc\nvhigh,vhigh,2,more,med,low,unacc\nvhigh,vhigh,2,more,med,med,unacc\nvhigh,vhigh,2,more,med,high,unacc\nvhigh,vhigh,2,more,big,low,unacc\nvhigh,vhigh,2,more,big,med,unacc\nvhigh,vhigh,2,more,big,high,unacc\nvhigh,vhigh,3,2,small,low,unacc\nvhigh,vhigh,3,2,small,med,unacc\nvhigh,vhigh,3,2,small,high,unacc\nvhigh,
# ...

# %%
import csv
with open("car.data","r") as f :
    car_data=csv.reader(f, delimiter="\n")
    for i in car_data:
        print(i)
# Out:
# ['vhigh,vhigh,2,2,small,low,unacc']
# ['vhigh,vhigh,2,2,small,med,unacc']
# ['vhigh,vhigh,2,2,small,high,unacc']
# ['vhigh,vhigh,2,2,med,low,unacc']
# ['vhigh,vhigh,2,2,med,med,unacc']
# ['vhigh,vhigh,2,2,med,high,unacc']
# ['vhigh,vhigh,2,2,big,low,unacc']
# ['vhigh,vhigh,2,2,big,med,unacc']
# ['vhigh,vhigh,2,2,big,high,unacc']
# ['vhigh,vhigh,2,4,small,low,unacc']
# ['vhigh,vhigh,2,4,small,med,unacc']
# ['vhigh,vhigh,2,4,small,high,unacc']
# ['vhigh,vhigh,2,4,med,low,unacc']
# ['vhigh,vhigh,2,4,med,med,unacc']
# ['vhigh,vhigh,2,4,med,high,unacc']
# ['vhigh,vhigh,2,4,big,low,unacc']
# ['vhigh,vhigh,2,4,big,med,unacc']
# ['vhigh,vhigh,2,4,big,high,unacc']
# ['vhigh,vhigh,2,more,small,low,unacc']
# ['vhigh,vhigh,2,more,small,med,unacc']
# ['vhigh,vhigh,2,more,small,high,unacc']
# ['vhigh,vhigh,2,more,med,low,unacc']
# ['vhigh,vhigh,2,more,med,med,unacc']
# ['vhigh,vhigh,2,more,med,high,unacc']
# ['vhigh,vhigh,2,more,big,low,unacc']
# ['vhigh,vhigh,2,more,big,med,unacc']
# ...

# %%
import csv
with open("car.data" , 'r') as f :
    car_data=csv.reader(f, delimiter="\n")
    for i in car_data:
        print(type(i),i)
        print(f'insert into car1 data values ({str(i[0])})')
        #cursor.execute(f'insert into car1 data values ({str(i[0])})')   
        
    for i in car_data:
        cursor.execute(f'insert into car1 data values ({str(i[0])})') 
    
    mydb.commit()
# Out:
# <class 'list'> ['vhigh,vhigh,2,2,small,low,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,small,low,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,small,med,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,small,med,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,small,high,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,small,high,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,med,low,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,med,low,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,med,med,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,med,med,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,med,high,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,med,high,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,big,low,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,big,low,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,big,med,unacc']
# insert into car1 data values (vhigh,vhigh,2,2,big,med,unacc)
# <class 'list'> ['vhigh,vhigh,2,2,big,high,unacc']
# ...

# %%
import pandas as pd

# %%
pd.read_sql("select * from car.car1", mydb)
# Out:
# Empty DataFrame
# Columns: [buying, maint, doors, persons, lug_boot, safety, class]
# Index: []
